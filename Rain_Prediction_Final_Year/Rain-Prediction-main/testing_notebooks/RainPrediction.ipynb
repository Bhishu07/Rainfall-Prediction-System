# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
import scipy.stats as stats
from sklearn.model_selection import train_test_split
from collections import Counter
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
import joblib
# Out:
# E:\Python\Python39\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
df = pd.read_csv("weatherAUS.csv")
pd.set_option("display.max_columns", None)
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am WindDir3pm  \
# 0            NaN           W           44.0          W        WNW
# 1            NaN         WNW           44.0        NNW        WSW
# 2            NaN         WSW           46.0          W        WSW
# 3            NaN          NE           24.0         SE          E
# 4            NaN           W           41.0        ENE         NW
# ...          ...         ...            ...        ...        ...
# 145455       NaN           E           31.0         SE        ENE
# 145456       NaN         NNW           22.0         SE          N
# 145457       NaN           N           37.0         SE        WNW
# 145458       NaN          SE           28.0        SSE          N
# 145459       NaN         NaN            NaN        ESE        ESE
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0               20.0          24.0         71.0         22.0       1007.7
# 1                4.0          22.0         44.0         25.0       1010.6
# 2               19.0          26.0         38.0         30.0       1007.6
# 3               11.0           9.0         45.0         16.0       1017.6
# 4                7.0          20.0         82.0         33.0       1010.8
# ...              ...           ...          ...          ...          ...
# 145455          13.0          11.0         51.0         24.0       1024.6
# 145456          13.0           9.0         56.0         21.0       1023.5
# 145457           9.0           9.0         53.0         24.0       1021.0
# 145458          13.0           7.0         51.0         24.0       1019.4
# 145459          17.0          17.0         62.0         36.0       1020.2
#
#         Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm RainToday  \
# 0            1007.1       8.0       NaN     16.9     21.8        No
# 1            1007.8       NaN       NaN     17.2     24.3        No
# 2            1008.7       NaN       2.0     21.0     23.2        No
# 3            1012.8       NaN       NaN     18.1     26.5        No
# 4            1006.0       7.0       8.0     17.8     29.7        No
# ...             ...       ...       ...      ...      ...       ...
# 145455       1020.3       NaN       NaN     10.1     22.4        No
# 145456       1019.1       NaN       NaN     10.9     24.5        No
# 145457       1016.8       NaN       NaN     12.5     26.1        No
# 145458       1016.5       3.0       2.0     15.1     26.0        No
# 145459       1017.9       8.0       8.0     15.0     20.9        No
#
#        RainTomorrow
# 0                No
# 1                No
# 2                No
# 3                No
# 4                No
# ...             ...
# 145455           No
# 145456           No
# 145457           No
# 145458           No
# 145459          NaN
#
# [145460 rows x 23 columns]

# %%
numerical_feature = [feature for feature in df.columns if df[feature].dtypes != 'O']
discrete_feature=[feature for feature in numerical_feature if len(df[feature].unique())<25]
continuous_feature = [feature for feature in numerical_feature if feature not in discrete_feature]
categorical_feature = [feature for feature in df.columns if feature not in numerical_feature]
print("Numerical Features Count {}".format(len(numerical_feature)))
print("Discrete feature Count {}".format(len(discrete_feature)))
print("Continuous feature Count {}".format(len(continuous_feature)))
print("Categorical feature Count {}".format(len(categorical_feature)))
# Out:
# Numerical Features Count 16
# Discrete feature Count 2
# Continuous feature Count 14
# Categorical feature Count 7

# %%
# Handle Missing Values
df.isnull().sum()*100/len(df)
# Out:
# Date              0.000000
# Location          0.000000
# MinTemp           1.020899
# MaxTemp           0.866905
# Rainfall          2.241853
# Evaporation      43.166506
# Sunshine         48.009762
# WindGustDir       7.098859
# WindGustSpeed     7.055548
# WindDir9am        7.263853
# WindDir3pm        2.906641
# WindSpeed9am      1.214767
# WindSpeed3pm      2.105046
# Humidity9am       1.824557
# Humidity3pm       3.098446
# Pressure9am      10.356799
# Pressure3pm      10.331363
# Cloud9am         38.421559
# Cloud3pm         40.807095
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64

# %%
print(numerical_feature)
# Out:
# ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm']

# %%
def randomsampleimputation(df, variable):
    df[variable]=df[variable]
    random_sample=df[variable].dropna().sample(df[variable].isnull().sum(),random_state=0)
    random_sample.index=df[df[variable].isnull()].index
    df.loc[df[variable].isnull(),variable]=random_sample

# %%
randomsampleimputation(df, "Cloud9am")
randomsampleimputation(df, "Cloud3pm")
randomsampleimputation(df, "Evaporation")
randomsampleimputation(df, "Sunshine")

# %%
df.isnull().sum()*100/len(df)
# Out:
# Date              0.000000
# Location          0.000000
# MinTemp           1.020899
# MaxTemp           0.866905
# Rainfall          2.241853
# Evaporation       0.000000
# Sunshine          0.000000
# WindGustDir       7.098859
# WindGustSpeed     7.055548
# WindDir9am        7.263853
# WindDir3pm        2.906641
# WindSpeed9am      1.214767
# WindSpeed3pm      2.105046
# Humidity9am       1.824557
# Humidity3pm       3.098446
# Pressure9am      10.356799
# Pressure3pm      10.331363
# Cloud9am          0.000000
# Cloud3pm          0.000000
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64

# %%
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          2.4
# 1       2008-12-02   Albury      7.4     25.1       0.0          3.6
# 2       2008-12-03   Albury     12.9     25.7       0.0          2.6
# 3       2008-12-04   Albury      9.2     28.0       0.0         18.4
# 4       2008-12-05   Albury     17.5     32.3       1.0          5.4
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          1.4
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          7.6
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          6.8
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          2.6
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          1.4
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am WindDir3pm  \
# 0            8.3           W           44.0          W        WNW
# 1           10.0         WNW           44.0        NNW        WSW
# 2            4.4         WSW           46.0          W        WSW
# 3            8.9          NE           24.0         SE          E
# 4            3.0           W           41.0        ENE         NW
# ...          ...         ...            ...        ...        ...
# 145455       7.8           E           31.0         SE        ENE
# 145456      13.5         NNW           22.0         SE          N
# 145457      11.0           N           37.0         SE        WNW
# 145458      13.2          SE           28.0        SSE          N
# 145459       0.7         NaN            NaN        ESE        ESE
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0               20.0          24.0         71.0         22.0       1007.7
# 1                4.0          22.0         44.0         25.0       1010.6
# 2               19.0          26.0         38.0         30.0       1007.6
# 3               11.0           9.0         45.0         16.0       1017.6
# 4                7.0          20.0         82.0         33.0       1010.8
# ...              ...           ...          ...          ...          ...
# 145455          13.0          11.0         51.0         24.0       1024.6
# 145456          13.0           9.0         56.0         21.0       1023.5
# 145457           9.0           9.0         53.0         24.0       1021.0
# 145458          13.0           7.0         51.0         24.0       1019.4
# 145459          17.0          17.0         62.0         36.0       1020.2
#
#         Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm RainToday  \
# 0            1007.1       8.0       0.0     16.9     21.8        No
# 1            1007.8       7.0       1.0     17.2     24.3        No
# 2            1008.7       8.0       2.0     21.0     23.2        No
# 3            1012.8       0.0       5.0     18.1     26.5        No
# 4            1006.0       7.0       8.0     17.8     29.7        No
# ...             ...       ...       ...      ...      ...       ...
# 145455       1020.3       1.0       1.0     10.1     22.4        No
# 145456       1019.1       8.0       5.0     10.9     24.5        No
# 145457       1016.8       8.0       1.0     12.5     26.1        No
# 145458       1016.5       3.0       2.0     15.1     26.0        No
# 145459       1017.9       8.0       8.0     15.0     20.9        No
#
#        RainTomorrow
# 0                No
# 1                No
# 2                No
# 3                No
# 4                No
# ...             ...
# 145455           No
# 145456           No
# 145457           No
# 145458           No
# 145459          NaN
#
# [145460 rows x 23 columns]

# %%
corrmat = df.corr(method = "spearman")
plt.figure(figsize=(15,15))
#plot heat map
g=sns.heatmap(corrmat,annot=True)

# %%
for feature in continuous_feature:
    data=df.copy()
    sns.distplot(df[feature])
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.figure(figsize=(15,15))
    plt.show()
# Out:
# E:\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#A for loop is used to plot a boxplot for all the continuous features to see the outliers
for feature in continuous_feature:
    data=df.copy()
    sns.boxplot(data[feature])
    plt.title(feature)
    plt.figure(figsize=(10,10))
# Out:
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
for feature in continuous_feature:
    if(df[feature].isnull().sum()*100/len(df))>0:
        df[feature] = df[feature].fillna(df[feature].median())

# %%
df.isnull().sum()*100/len(df)
# Out:
# Date             0.000000
# Location         0.000000
# MinTemp          0.000000
# MaxTemp          0.000000
# Rainfall         0.000000
# Evaporation      0.000000
# Sunshine         0.000000
# WindGustDir      7.098859
# WindGustSpeed    0.000000
# WindDir9am       7.263853
# WindDir3pm       2.906641
# WindSpeed9am     0.000000
# WindSpeed3pm     0.000000
# Humidity9am      0.000000
# Humidity3pm      0.000000
# Pressure9am      0.000000
# Pressure3pm      0.000000
# Cloud9am         0.000000
# Cloud3pm         0.000000
# Temp9am          0.000000
# Temp3pm          0.000000
# RainToday        2.241853
# RainTomorrow     2.245978
# dtype: float64

# %%
discrete_feature
# Out:
# ['Cloud9am', 'Cloud3pm']

# %%
def mode_nan(df,variable):
    mode=df[variable].value_counts().index[0]
    df[variable].fillna(mode,inplace=True)
mode_nan(df,"Cloud9am")
mode_nan(df,"Cloud3pm")

# %%
df["RainToday"] = pd.get_dummies(df["RainToday"], drop_first = True)
df["RainTomorrow"] = pd.get_dummies(df["RainTomorrow"], drop_first = True)
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          2.4
# 1       2008-12-02   Albury      7.4     25.1       0.0          3.6
# 2       2008-12-03   Albury     12.9     25.7       0.0          2.6
# 3       2008-12-04   Albury      9.2     28.0       0.0         18.4
# 4       2008-12-05   Albury     17.5     32.3       1.0          5.4
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          1.4
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          7.6
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          6.8
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          2.6
# 145459  2017-06-25    Uluru     14.9     22.6       0.0          1.4
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am WindDir3pm  \
# 0            8.3           W           44.0          W        WNW
# 1           10.0         WNW           44.0        NNW        WSW
# 2            4.4         WSW           46.0          W        WSW
# 3            8.9          NE           24.0         SE          E
# 4            3.0           W           41.0        ENE         NW
# ...          ...         ...            ...        ...        ...
# 145455       7.8           E           31.0         SE        ENE
# 145456      13.5         NNW           22.0         SE          N
# 145457      11.0           N           37.0         SE        WNW
# 145458      13.2          SE           28.0        SSE          N
# 145459       0.7         NaN           39.0        ESE        ESE
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0               20.0          24.0         71.0         22.0       1007.7
# 1                4.0          22.0         44.0         25.0       1010.6
# 2               19.0          26.0         38.0         30.0       1007.6
# 3               11.0           9.0         45.0         16.0       1017.6
# 4                7.0          20.0         82.0         33.0       1010.8
# ...              ...           ...          ...          ...          ...
# 145455          13.0          11.0         51.0         24.0       1024.6
# 145456          13.0           9.0         56.0         21.0       1023.5
# 145457           9.0           9.0         53.0         24.0       1021.0
# 145458          13.0           7.0         51.0         24.0       1019.4
# 145459          17.0          17.0         62.0         36.0       1020.2
#
#         Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0            1007.1       8.0       0.0     16.9     21.8          0
# 1            1007.8       7.0       1.0     17.2     24.3          0
# 2            1008.7       8.0       2.0     21.0     23.2          0
# 3            1012.8       0.0       5.0     18.1     26.5          0
# 4            1006.0       7.0       8.0     17.8     29.7          0
# ...             ...       ...       ...      ...      ...        ...
# 145455       1020.3       1.0       1.0     10.1     22.4          0
# 145456       1019.1       8.0       5.0     10.9     24.5          0
# 145457       1016.8       8.0       1.0     12.5     26.1          0
# 145458       1016.5       3.0       2.0     15.1     26.0          0
# 145459       1017.9       8.0       8.0     15.0     20.9          0
#
#         RainTomorrow
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 145455             0
# 145456             0
# 145457             0
# 145458             0
# 145459             0
#
# [145460 rows x 23 columns]

# %%
for feature in categorical_feature:
    print(feature, (df.groupby([feature])["RainTomorrow"].mean().sort_values(ascending = False)).index)
# Out:
# Date Index(['2007-11-01', '2007-12-15', '2008-02-03', '2008-01-31', '2008-01-30',
#        '2008-01-19', '2008-01-18', '2008-01-16', '2008-01-12', '2007-11-30',
#        ...
#        '2008-05-08', '2008-05-09', '2008-01-03', '2008-01-02', '2008-05-10',
#        '2008-05-11', '2008-05-12', '2008-05-13', '2008-05-14', '2007-12-25'],
#       dtype='object', name='Date', length=3436)
# Location Index(['Portland', 'Walpole', 'Cairns', 'Dartmoor', 'NorfolkIsland',
#        'MountGambier', 'Albany', 'Witchcliffe', 'CoffsHarbour', 'MountGinini',
#        'NorahHead', 'Darwin', 'Sydney', 'SydneyAirport', 'Ballarat',
#        'GoldCoast', 'Watsonia', 'Newcastle', 'Hobart', 'Wollongong',
#        'Williamtown', 'Launceston', 'Brisbane', 'MelbourneAirport', 'Adelaide',
#        'Sale', 'Albury', 'Perth', 'Melbourne', 'Nuriootpa', 'Penrith',
#        'BadgerysCreek', 'PerthAirport', 'Tuggeranong', 'Richmond', 'Bendigo',
#        'Canberra', 'WaggaWagga', 'Townsville', 'Katherine', 'PearceRAAF',
#        'SalmonGums', 'Nhil', 'Moree', 'Cobar', 'Mildura', 'AliceSprings',
#        'Uluru', 'Woomera'],
#       dtype='object', name='Location')
# WindGustDir Index(['NNW', 'NW', 'WNW', 'N', 'W', 'WSW', 'NNE', 'S', 'SSW', 'SW', 'SSE',
#        'NE', 'SE', 'ESE', 'ENE', 'E'],
#       dtype='object', name='WindGustDir')
# WindDir9am Index(['NNW', 'N', 'NW', 'NNE', 'WNW', 'W', 'WSW', 'SW', 'SSW', 'NE', 'S',
#        'SSE', 'ENE', 'SE', 'ESE', 'E'],
#       dtype='object', name='WindDir9am')
# WindDir3pm Index(['NW', 'NNW', 'N', 'WNW', 'W', 'NNE', 'WSW', 'SSW', 'S', 'SW', 'SE',
#        'NE', 'SSE', 'ENE', 'E', 'ESE'],
#       dtype='object', name='WindDir3pm')
# RainToday UInt64Index([1, 0], dtype='uint64', name='RainToday')
# RainTomorrow UInt64Index([1, 0], dtype='uint64', name='RainTomorrow')

# %%
windgustdir = {'NNW':0, 'NW':1, 'WNW':2, 'N':3, 'W':4, 'WSW':5, 'NNE':6, 'S':7, 'SSW':8, 'SW':9, 'SSE':10,
       'NE':11, 'SE':12, 'ESE':13, 'ENE':14, 'E':15}
winddir9am = {'NNW':0, 'N':1, 'NW':2, 'NNE':3, 'WNW':4, 'W':5, 'WSW':6, 'SW':7, 'SSW':8, 'NE':9, 'S':10,
       'SSE':11, 'ENE':12, 'SE':13, 'ESE':14, 'E':15}
winddir3pm = {'NW':0, 'NNW':1, 'N':2, 'WNW':3, 'W':4, 'NNE':5, 'WSW':6, 'SSW':7, 'S':8, 'SW':9, 'SE':10,
       'NE':11, 'SSE':12, 'ENE':13, 'E':14, 'ESE':15}
df["WindGustDir"] = df["WindGustDir"].map(windgustdir)
df["WindDir9am"] = df["WindDir9am"].map(winddir9am)
df["WindDir3pm"] = df["WindDir3pm"].map(winddir3pm)

# %%
df["WindGustDir"] = df["WindGustDir"].fillna(df["WindGustDir"].value_counts().index[0])
df["WindDir9am"] = df["WindDir9am"].fillna(df["WindDir9am"].value_counts().index[0])
df["WindDir3pm"] = df["WindDir3pm"].fillna(df["WindDir3pm"].value_counts().index[0])

# %%
df.isnull().sum()*100/len(df)
# Out:
# Date             0.0
# Location         0.0
# MinTemp          0.0
# MaxTemp          0.0
# Rainfall         0.0
# Evaporation      0.0
# Sunshine         0.0
# WindGustDir      0.0
# WindGustSpeed    0.0
# WindDir9am       0.0
# WindDir3pm       0.0
# WindSpeed9am     0.0
# WindSpeed3pm     0.0
# Humidity9am      0.0
# Humidity3pm      0.0
# Pressure9am      0.0
# Pressure3pm      0.0
# Cloud9am         0.0
# Cloud3pm         0.0
# Temp9am          0.0
# Temp3pm          0.0
# RainToday        0.0
# RainTomorrow     0.0
# dtype: float64

# %%
df1 = df.groupby(["Location"])["RainTomorrow"].value_counts().sort_values().unstack()

# %%
df1
# Out:
# RainTomorrow         0     1
# Location
# Adelaide          2505   688
# Albany            2138   902
# Albury            2422   618
# AliceSprings      2796   244
# BadgerysCreek     2426   583
# Ballarat          2259   781
# Bendigo           2478   562
# Brisbane          2484   709
# Cairns            2090   950
# Canberra          2807   629
# Cobar             2623   386
# CoffsHarbour      2140   869
# Dartmoor          2087   922
# Darwin            2341   852
# GoldCoast         2265   775
# Hobart            2432   761
# Katherine         1313   265
# Launceston        2341   699
# Melbourne         2557   636
# MelbourneAirport  2356   653
# Mildura           2682   327
# Moree             2615   394
# MountGambier      2120   920
# MountGinini       2221   819
# Newcastle         2308   731
# Nhil              1336   242
# NorahHead         2196   808
# NorfolkIsland     2090   919
# Nuriootpa         2417   592
# PearceRAAF        2504   505
# Penrith           2444   595
# Perth             2548   645
# PerthAirport      2442   567
# Portland          1914  1095
# Richmond          2449   560
# Sale              2366   643
# SalmonGums        2529   472
# Sydney            2479   865
# SydneyAirport     2235   774
# Townsville        2521   519
# Tuggeranong       2471   568
# Uluru             1462   116
# WaggaWagga        2473   536
# Walpole           2057   949
# Watsonia          2271   738
# Williamtown       2309   700
# Witchcliffe       2130   879
# Wollongong        2327   713
# Woomera           2807   202

# %%
df1[1].sort_values(ascending = False)
# Out:
# Location
# Portland            1095
# Cairns               950
# Walpole              949
# Dartmoor             922
# MountGambier         920
# NorfolkIsland        919
# Albany               902
# Witchcliffe          879
# CoffsHarbour         869
# Sydney               865
# Darwin               852
# MountGinini          819
# NorahHead            808
# Ballarat             781
# GoldCoast            775
# SydneyAirport        774
# Hobart               761
# Watsonia             738
# Newcastle            731
# Wollongong           713
# Brisbane             709
# Williamtown          700
# Launceston           699
# Adelaide             688
# MelbourneAirport     653
# Perth                645
# Sale                 643
# Melbourne            636
# Canberra             629
# Albury               618
# Penrith              595
# Nuriootpa            592
# BadgerysCreek        583
# Tuggeranong          568
# PerthAirport         567
# Bendigo              562
# Richmond             560
# WaggaWagga           536
# Townsville           519
# PearceRAAF           505
# SalmonGums           472
# Moree                394
# Cobar                386
# Mildura              327
# Katherine            265
# AliceSprings         244
# Nhil                 242
# Woomera              202
# Uluru                116
# Name: 1, dtype: int64

# %%
df1[1].sort_values(ascending = False).index
# Out:
# Index(['Portland', 'Cairns', 'Walpole', 'Dartmoor', 'MountGambier',
#        'NorfolkIsland', 'Albany', 'Witchcliffe', 'CoffsHarbour', 'Sydney',
#        'Darwin', 'MountGinini', 'NorahHead', 'Ballarat', 'GoldCoast',
#        'SydneyAirport', 'Hobart', 'Watsonia', 'Newcastle', 'Wollongong',
#        'Brisbane', 'Williamtown', 'Launceston', 'Adelaide', 'MelbourneAirport',
#        'Perth', 'Sale', 'Melbourne', 'Canberra', 'Albury', 'Penrith',
#        'Nuriootpa', 'BadgerysCreek', 'Tuggeranong', 'PerthAirport', 'Bendigo',
#        'Richmond', 'WaggaWagga', 'Townsville', 'PearceRAAF', 'SalmonGums',
#        'Moree', 'Cobar', 'Mildura', 'Katherine', 'AliceSprings', 'Nhil',
#        'Woomera', 'Uluru'],
#       dtype='object', name='Location')

# %%
len(df1[1].sort_values(ascending = False).index)
# Out:
# 49

# %%
location = {'Portland':1, 'Cairns':2, 'Walpole':3, 'Dartmoor':4, 'MountGambier':5,
       'NorfolkIsland':6, 'Albany':7, 'Witchcliffe':8, 'CoffsHarbour':9, 'Sydney':10,
       'Darwin':11, 'MountGinini':12, 'NorahHead':13, 'Ballarat':14, 'GoldCoast':15,
       'SydneyAirport':16, 'Hobart':17, 'Watsonia':18, 'Newcastle':19, 'Wollongong':20,
       'Brisbane':21, 'Williamtown':22, 'Launceston':23, 'Adelaide':24, 'MelbourneAirport':25,
       'Perth':26, 'Sale':27, 'Melbourne':28, 'Canberra':29, 'Albury':30, 'Penrith':31,
       'Nuriootpa':32, 'BadgerysCreek':33, 'Tuggeranong':34, 'PerthAirport':35, 'Bendigo':36,
       'Richmond':37, 'WaggaWagga':38, 'Townsville':39, 'PearceRAAF':40, 'SalmonGums':41,
       'Moree':42, 'Cobar':43, 'Mildura':44, 'Katherine':45, 'AliceSprings':46, 'Nhil':47,
       'Woomera':48, 'Uluru':49}
df["Location"] = df["Location"].map(location)

# %%
df["Date"] = pd.to_datetime(df["Date"], format = "%Y-%m-%dT", errors = "coerce")

# %%
df["Date_month"] = df["Date"].dt.month
df["Date_day"] = df["Date"].dt.day

# %%
df
# Out:
#              Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0      2008-12-01        30     13.4     22.9       0.6          2.4
# 1      2008-12-02        30      7.4     25.1       0.0          3.6
# 2      2008-12-03        30     12.9     25.7       0.0          2.6
# 3      2008-12-04        30      9.2     28.0       0.0         18.4
# 4      2008-12-05        30     17.5     32.3       1.0          5.4
# ...           ...       ...      ...      ...       ...          ...
# 145455 2017-06-21        49      2.8     23.4       0.0          1.4
# 145456 2017-06-22        49      3.6     25.3       0.0          7.6
# 145457 2017-06-23        49      5.4     26.9       0.0          6.8
# 145458 2017-06-24        49      7.8     27.0       0.0          2.6
# 145459 2017-06-25        49     14.9     22.6       0.0          1.4
#
#         Sunshine  WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  \
# 0            8.3          4.0           44.0         5.0         3.0
# 1           10.0          2.0           44.0         0.0         6.0
# 2            4.4          5.0           46.0         5.0         6.0
# 3            8.9         11.0           24.0        13.0        14.0
# 4            3.0          4.0           41.0        12.0         0.0
# ...          ...          ...            ...         ...         ...
# 145455       7.8         15.0           31.0        13.0        13.0
# 145456      13.5          0.0           22.0        13.0         2.0
# 145457      11.0          3.0           37.0        13.0         3.0
# 145458      13.2         12.0           28.0        11.0         2.0
# 145459       0.7          4.0           39.0        14.0        15.0
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0               20.0          24.0         71.0         22.0       1007.7
# 1                4.0          22.0         44.0         25.0       1010.6
# 2               19.0          26.0         38.0         30.0       1007.6
# 3               11.0           9.0         45.0         16.0       1017.6
# 4                7.0          20.0         82.0         33.0       1010.8
# ...              ...           ...          ...          ...          ...
# 145455          13.0          11.0         51.0         24.0       1024.6
# 145456          13.0           9.0         56.0         21.0       1023.5
# 145457           9.0           9.0         53.0         24.0       1021.0
# 145458          13.0           7.0         51.0         24.0       1019.4
# 145459          17.0          17.0         62.0         36.0       1020.2
#
#         Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0            1007.1       8.0       0.0     16.9     21.8          0
# 1            1007.8       7.0       1.0     17.2     24.3          0
# 2            1008.7       8.0       2.0     21.0     23.2          0
# 3            1012.8       0.0       5.0     18.1     26.5          0
# 4            1006.0       7.0       8.0     17.8     29.7          0
# ...             ...       ...       ...      ...      ...        ...
# 145455       1020.3       1.0       1.0     10.1     22.4          0
# 145456       1019.1       8.0       5.0     10.9     24.5          0
# 145457       1016.8       8.0       1.0     12.5     26.1          0
# 145458       1016.5       3.0       2.0     15.1     26.0          0
# 145459       1017.9       8.0       8.0     15.0     20.9          0
#
#         RainTomorrow  Date_month  Date_day
# 0                  0          12         1
# 1                  0          12         2
# 2                  0          12         3
# 3                  0          12         4
# 4                  0          12         5
# ...              ...         ...       ...
# 145455             0           6        21
# 145456             0           6        22
# 145457             0           6        23
# 145458             0           6        24
# 145459             0           6        25
#
# [145460 rows x 25 columns]

# %%
corrmat = df.corr()
plt.figure(figsize=(15,15))
#plot heat map
g=sns.heatmap(corrmat,annot=True)

# %%
sns.countplot(df["RainTomorrow"])
# Out:
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='RainTomorrow', ylabel='count'>

# %%
df
# Out:
#              Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0      2008-12-01        30     13.4     22.9       0.6          2.4
# 1      2008-12-02        30      7.4     25.1       0.0          3.6
# 2      2008-12-03        30     12.9     25.7       0.0          2.6
# 3      2008-12-04        30      9.2     28.0       0.0         18.4
# 4      2008-12-05        30     17.5     32.3       1.0          5.4
# ...           ...       ...      ...      ...       ...          ...
# 145455 2017-06-21        49      2.8     23.4       0.0          1.4
# 145456 2017-06-22        49      3.6     25.3       0.0          7.6
# 145457 2017-06-23        49      5.4     26.9       0.0          6.8
# 145458 2017-06-24        49      7.8     27.0       0.0          2.6
# 145459 2017-06-25        49     14.9     22.6       0.0          1.4
#
#         Sunshine  WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  \
# 0            8.3          4.0           44.0         5.0         3.0
# 1           10.0          2.0           44.0         0.0         6.0
# 2            4.4          5.0           46.0         5.0         6.0
# 3            8.9         11.0           24.0        13.0        14.0
# 4            3.0          4.0           41.0        12.0         0.0
# ...          ...          ...            ...         ...         ...
# 145455       7.8         15.0           31.0        13.0        13.0
# 145456      13.5          0.0           22.0        13.0         2.0
# 145457      11.0          3.0           37.0        13.0         3.0
# 145458      13.2         12.0           28.0        11.0         2.0
# 145459       0.7          4.0           39.0        14.0        15.0
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0               20.0          24.0         71.0         22.0       1007.7
# 1                4.0          22.0         44.0         25.0       1010.6
# 2               19.0          26.0         38.0         30.0       1007.6
# 3               11.0           9.0         45.0         16.0       1017.6
# 4                7.0          20.0         82.0         33.0       1010.8
# ...              ...           ...          ...          ...          ...
# 145455          13.0          11.0         51.0         24.0       1024.6
# 145456          13.0           9.0         56.0         21.0       1023.5
# 145457           9.0           9.0         53.0         24.0       1021.0
# 145458          13.0           7.0         51.0         24.0       1019.4
# 145459          17.0          17.0         62.0         36.0       1020.2
#
#         Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0            1007.1       8.0       0.0     16.9     21.8          0
# 1            1007.8       7.0       1.0     17.2     24.3          0
# 2            1008.7       8.0       2.0     21.0     23.2          0
# 3            1012.8       0.0       5.0     18.1     26.5          0
# 4            1006.0       7.0       8.0     17.8     29.7          0
# ...             ...       ...       ...      ...      ...        ...
# 145455       1020.3       1.0       1.0     10.1     22.4          0
# 145456       1019.1       8.0       5.0     10.9     24.5          0
# 145457       1016.8       8.0       1.0     12.5     26.1          0
# 145458       1016.5       3.0       2.0     15.1     26.0          0
# 145459       1017.9       8.0       8.0     15.0     20.9          0
#
#         RainTomorrow  Date_month  Date_day
# 0                  0          12         1
# 1                  0          12         2
# 2                  0          12         3
# 3                  0          12         4
# 4                  0          12         5
# ...              ...         ...       ...
# 145455             0           6        21
# 145456             0           6        22
# 145457             0           6        23
# 145458             0           6        24
# 145459             0           6        25
#
# [145460 rows x 25 columns]

# %%
for feature in continuous_feature:
    data=df.copy()
    sns.boxplot(data[feature])
    plt.title(feature)
    plt.figure(figsize=(10,10))
# Out:
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
for feature in continuous_feature:
    print(feature)
# Out:
# MinTemp
# MaxTemp
# Rainfall
# Evaporation
# Sunshine
# WindGustSpeed
# WindSpeed9am
# WindSpeed3pm
# Humidity9am
# Humidity3pm
# Pressure9am
# Pressure3pm
# Temp9am
# Temp3pm

# %%
IQR=df.MinTemp.quantile(0.75)-df.MinTemp.quantile(0.25)
lower_bridge=df.MinTemp.quantile(0.25)-(IQR*1.5)
upper_bridge=df.MinTemp.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -5.950000000000002 30.450000000000003

# %%
df.loc[df['MinTemp']>=30.45,'MinTemp']=30.45
df.loc[df['MinTemp']<=-5.95,'MinTemp']=-5.95

# %%
IQR=df.MaxTemp.quantile(0.75)-df.MaxTemp.quantile(0.25)
lower_bridge=df.MaxTemp.quantile(0.25)-(IQR*1.5)
upper_bridge=df.MaxTemp.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 2.700000000000001 43.5

# %%
df.loc[df['MaxTemp']>=43.5,'MaxTemp']=43.5
df.loc[df['MaxTemp']<=2.7,'MaxTemp']=2.7

# %%
IQR=df.Rainfall.quantile(0.75)-df.Rainfall.quantile(0.25)
lower_bridge=df.Rainfall.quantile(0.25)-(IQR*1.5)
upper_bridge=df.Rainfall.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -0.8999999999999999 1.5

# %%
df.loc[df['Rainfall']>=1.5,'Rainfall']=1.5
df.loc[df['Rainfall']<=-0.89,'Rainfall']=-0.89

# %%
IQR=df.Evaporation.quantile(0.75)-df.Evaporation.quantile(0.25)
lower_bridge=df.Evaporation.quantile(0.25)-(IQR*1.5)
upper_bridge=df.Evaporation.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -4.600000000000001 14.600000000000001

# %%
df.loc[df['Evaporation']>=14.6,'Evaporation']=14.6
df.loc[df['Evaporation']<=-4.6,'Evaporation']=-4.6

# %%
IQR=df.WindGustSpeed.quantile(0.75)-df.WindGustSpeed.quantile(0.25)
lower_bridge=df.WindGustSpeed.quantile(0.25)-(IQR*1.5)
upper_bridge=df.WindGustSpeed.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 8.5 68.5

# %%
df.loc[df['WindGustSpeed']>=68.5,'WindGustSpeed']=68.5
df.loc[df['WindGustSpeed']<=8.5,'WindGustSpeed']=8.5

# %%
IQR=df.WindSpeed9am.quantile(0.75)-df.WindSpeed9am.quantile(0.25)
lower_bridge=df.WindSpeed9am.quantile(0.25)-(IQR*1.5)
upper_bridge=df.WindSpeed9am.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -11.0 37.0

# %%
df.loc[df['WindSpeed9am']>=37,'WindSpeed9am']=37
df.loc[df['WindSpeed9am']<=-11,'WindSpeed9am']=-11

# %%
IQR=df.WindSpeed3pm.quantile(0.75)-df.WindSpeed3pm.quantile(0.25)
lower_bridge=df.WindSpeed3pm.quantile(0.25)-(IQR*1.5)
upper_bridge=df.WindSpeed3pm.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -3.5 40.5

# %%
df.loc[df['WindSpeed3pm']>40.5,'WindSpeed3pm']=40.5
df.loc[df['WindSpeed3pm']<=-3.5,'WindSpeed3pm']=-3.5

# %%
IQR=df.Humidity9am.quantile(0.75)-df.Humidity9am.quantile(0.25)
lower_bridge=df.Humidity9am.quantile(0.25)-(IQR*1.5)
upper_bridge=df.Humidity9am.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 18.0 122.0

# %%
df.loc[df['Humidity9am']>=122,'Humidity9am']=122
df.loc[df['Humidity9am']<=18,'Humidity9am']=18

# %%
IQR=df.Pressure9am.quantile(0.75)-df.Pressure9am.quantile(0.25)
lower_bridge=df.Pressure9am.quantile(0.25)-(IQR*1.5)
upper_bridge=df.Pressure9am.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 1001.0500000000001 1034.25

# %%
df.loc[df['Pressure9am']>=1034.25,'Pressure9am']=1034.25
df.loc[df['Pressure9am']<=1001.05,'Pressure9am']=1001.05

# %%
IQR=df.Pressure3pm.quantile(0.75)-df.Pressure3pm.quantile(0.25)
lower_bridge=df.Pressure3pm.quantile(0.25)-(IQR*1.5)
upper_bridge=df.Pressure3pm.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 998.6500000000001 1031.85

# %%
df.loc[df['Pressure3pm']>=1031.85,'Pressure3pm']=1031.85
df.loc[df['Pressure3pm']<=998.65,'Pressure3pm']=998.65

# %%
IQR=df.Temp9am.quantile(0.75)-df.Temp9am.quantile(0.25)
lower_bridge=df.Temp9am.quantile(0.25)-(IQR*1.5)
upper_bridge=df.Temp9am.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -1.4999999999999982 35.3

# %%
df.loc[df['Temp9am']>=35.3,'Temp9am']=35.3
df.loc[df['Temp9am']<=-1.49,'Temp9am']=-1.49

# %%
IQR=df.Temp3pm.quantile(0.75)-df.Temp3pm.quantile(0.25)
lower_bridge=df.Temp3pm.quantile(0.25)-(IQR*1.5)
upper_bridge=df.Temp3pm.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 2.4499999999999993 40.45

# %%
df.loc[df['Temp3pm']>=40.45,'Temp3pm']=40.45
df.loc[df['Temp3pm']<=2.45,'Temp3pm']=2.45

# %%
for feature in continuous_feature:
    data=df.copy()
    sns.boxplot(data[feature])
    plt.title(feature)
    plt.figure(figsize=(10,10))
# Out:
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
def qq_plots(df, variable):
    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 1)
    df[variable].hist()
    plt.subplot(1, 2, 2)
    stats.probplot(df[variable], dist="norm", plot=plt)
    plt.show()

# %%
for feature in continuous_feature:
    print(feature)
    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 1)
    df[feature].hist()
    plt.subplot(1, 2, 2)
    stats.probplot(df[feature], dist="norm", plot=plt)
    plt.show()
# Out:
# MinTemp
# MaxTemp
# Rainfall
# Evaporation
# Sunshine
# WindGustSpeed
# WindSpeed9am
# WindSpeed3pm
# Humidity9am
# Humidity3pm
# Pressure9am
# Pressure3pm
# Temp9am
# Temp3pm

# %%
df.to_csv("preprocessed_1.csv", index=False)

# %%
X = df.drop(["RainTomorrow", "Date"], axis=1)
Y = df["RainTomorrow"]

# %%
# scaler = RobustScaler()
# X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size =0.2, stratify = Y, random_state = 0)

# %%
y_train
# Out:
# 43447     0
# 140904    0
# 54615     0
# 109793    0
# 74462     0
#          ..
# 106567    0
# 52791     1
# 56339     0
# 82299     1
# 115175    0
# Name: RainTomorrow, Length: 116368, dtype: uint8

# %%
sm=SMOTE(random_state=0)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)
print("The number of classes before fit {}".format(Counter(y_train)))
print("The number of classes after fit {}".format(Counter(y_train_res)))
# Out:
# The number of classes before fit Counter({0: 90866, 1: 25502})
# The number of classes after fit Counter({0: 90866, 1: 90866})

# %%
sm=SMOTE(random_state=0)
X_test_res, y_test_res = sm.fit_resample(X_test, y_test)
print("The number of classes before fit {}".format(Counter(y_test)))
print("The number of classes after fit {}".format(Counter(y_test_res)))
# Out:
# The number of classes before fit Counter({0: 22717, 1: 6375})
# The number of classes after fit Counter({0: 22717, 1: 22717})

# %%
cat = CatBoostClassifier(iterations=1000, eval_metric = "AUC")
cat.fit(X_train_res, y_train_res)
# Out:
# Custom logger is already specified. Specify more than one logger at same time is not thread safe.
# Learning rate set to 0.094997
# 0:	total: 46.5ms	remaining: 46.5s
# 1:	total: 102ms	remaining: 51.1s
# 2:	total: 152ms	remaining: 50.4s
# 3:	total: 206ms	remaining: 51.3s
# 4:	total: 245ms	remaining: 48.7s
# 5:	total: 283ms	remaining: 46.9s
# 6:	total: 318ms	remaining: 45.2s
# 7:	total: 355ms	remaining: 44.1s
# 8:	total: 387ms	remaining: 42.6s
# 9:	total: 419ms	remaining: 41.4s
# 10:	total: 452ms	remaining: 40.6s
# 11:	total: 495ms	remaining: 40.8s
# 12:	total: 535ms	remaining: 40.6s
# 13:	total: 563ms	remaining: 39.6s
# 14:	total: 589ms	remaining: 38.7s
# 15:	total: 615ms	remaining: 37.8s
# 16:	total: 644ms	remaining: 37.3s
# 17:	total: 675ms	remaining: 36.8s
# 18:	total: 711ms	remaining: 36.7s
# 19:	total: 746ms	remaining: 36.6s
# 20:	total: 775ms	remaining: 36.1s
# 21:	total: 804ms	remaining: 35.8s
# 22:	total: 837ms	remaining: 35.5s
# 23:	total: 869ms	remaining: 35.3s
# 24:	total: 903ms	remaining: 35.2s
# 25:	total: 940ms	remaining: 35.2s
# 26:	total: 975ms	remaining: 35.1s
# 27:	total: 1s	remaining: 34.8s
# 28:	total: 1.03s	remaining: 34.5s
# 29:	total: 1.06s	remaining: 34.3s
# 30:	total: 1.09s	remaining: 34.2s
# 31:	total: 1.13s	remaining: 34.1s
# 32:	total: 1.17s	remaining: 34.3s
# 33:	total: 1.2s	remaining: 34.2s
# 34:	total: 1.23s	remaining: 34s
# 35:	total: 1.27s	remaining: 33.9s
# 36:	total: 1.29s	remaining: 33.7s
# 37:	total: 1.32s	remaining: 33.5s
# 38:	total: 1.36s	remaining: 33.5s
# 39:	total: 1.39s	remaining: 33.4s
# 40:	total: 1.42s	remaining: 33.2s
# 41:	total: 1.45s	remaining: 33.1s
# 42:	total: 1.48s	remaining: 32.9s
# 43:	total: 1.51s	remaining: 32.7s
# 44:	total: 1.54s	remaining: 32.7s
# 45:	total: 1.57s	remaining: 32.7s
# 46:	total: 1.61s	remaining: 32.6s
# 47:	total: 1.64s	remaining: 32.5s
# 48:	total: 1.67s	remaining: 32.4s
# 49:	total: 1.7s	remaining: 32.4s
# 50:	total: 1.74s	remaining: 32.3s
# 51:	total: 1.77s	remaining: 32.4s
# 52:	total: 1.81s	remaining: 32.3s
# 53:	total: 1.85s	remaining: 32.5s
# 54:	total: 1.88s	remaining: 32.4s
# 55:	total: 1.91s	remaining: 32.2s
# 56:	total: 1.94s	remaining: 32.1s
# 57:	total: 1.98s	remaining: 32.1s
# 58:	total: 2.02s	remaining: 32.1s
# 59:	total: 2.05s	remaining: 32.1s
# 60:	total: 2.08s	remaining: 32s
# 61:	total: 2.12s	remaining: 32s
# 62:	total: 2.15s	remaining: 32s
# 63:	total: 2.19s	remaining: 32.1s
# 64:	total: 2.23s	remaining: 32.1s
# 65:	total: 2.26s	remaining: 32s
# 66:	total: 2.29s	remaining: 31.9s
# 67:	total: 2.32s	remaining: 31.8s
# 68:	total: 2.35s	remaining: 31.7s
# 69:	total: 2.39s	remaining: 31.8s
# 70:	total: 2.42s	remaining: 31.7s
# 71:	total: 2.46s	remaining: 31.7s
# 72:	total: 2.49s	remaining: 31.6s
# 73:	total: 2.51s	remaining: 31.4s
# 74:	total: 2.54s	remaining: 31.3s
# 75:	total: 2.57s	remaining: 31.2s
# 76:	total: 2.6s	remaining: 31.2s
# 77:	total: 2.63s	remaining: 31.1s
# 78:	total: 2.66s	remaining: 31s
# 79:	total: 2.69s	remaining: 30.9s
# 80:	total: 2.71s	remaining: 30.8s
# 81:	total: 2.74s	remaining: 30.7s
# 82:	total: 2.78s	remaining: 30.7s
# 83:	total: 2.81s	remaining: 30.6s
# 84:	total: 2.85s	remaining: 30.7s
# 85:	total: 2.88s	remaining: 30.6s
# 86:	total: 2.91s	remaining: 30.6s
# 87:	total: 2.94s	remaining: 30.5s
# 88:	total: 2.98s	remaining: 30.5s
# 89:	total: 3.01s	remaining: 30.5s
# 90:	total: 3.04s	remaining: 30.4s
# 91:	total: 3.08s	remaining: 30.4s
# 92:	total: 3.11s	remaining: 30.3s
# 93:	total: 3.13s	remaining: 30.2s
# 94:	total: 3.16s	remaining: 30.1s
# 95:	total: 3.19s	remaining: 30.1s
# 96:	total: 3.22s	remaining: 30s
# 97:	total: 3.25s	remaining: 29.9s
# 98:	total: 3.29s	remaining: 29.9s
# 99:	total: 3.32s	remaining: 29.9s
# 100:	total: 3.35s	remaining: 29.8s
# 101:	total: 3.38s	remaining: 29.7s
# 102:	total: 3.4s	remaining: 29.6s
# 103:	total: 3.43s	remaining: 29.6s
# 104:	total: 3.46s	remaining: 29.5s
# 105:	total: 3.49s	remaining: 29.4s
# 106:	total: 3.52s	remaining: 29.4s
# 107:	total: 3.54s	remaining: 29.3s
# 108:	total: 3.57s	remaining: 29.2s
# 109:	total: 3.6s	remaining: 29.1s
# 110:	total: 3.62s	remaining: 29s
# 111:	total: 3.65s	remaining: 29s
# 112:	total: 3.68s	remaining: 28.9s
# 113:	total: 3.71s	remaining: 28.8s
# 114:	total: 3.74s	remaining: 28.8s
# 115:	total: 3.77s	remaining: 28.7s
# 116:	total: 3.8s	remaining: 28.7s
# 117:	total: 3.83s	remaining: 28.6s
# 118:	total: 3.85s	remaining: 28.5s
# 119:	total: 3.88s	remaining: 28.5s
# 120:	total: 3.91s	remaining: 28.4s
# 121:	total: 3.94s	remaining: 28.3s
# 122:	total: 3.97s	remaining: 28.3s
# 123:	total: 4s	remaining: 28.3s
# 124:	total: 4.03s	remaining: 28.2s
# 125:	total: 4.05s	remaining: 28.1s
# 126:	total: 4.08s	remaining: 28.1s
# 127:	total: 4.12s	remaining: 28s
# 128:	total: 4.14s	remaining: 28s
# 129:	total: 4.17s	remaining: 27.9s
# 130:	total: 4.21s	remaining: 27.9s
# 131:	total: 4.23s	remaining: 27.8s
# 132:	total: 4.26s	remaining: 27.8s
# 133:	total: 4.29s	remaining: 27.7s
# 134:	total: 4.32s	remaining: 27.7s
# 135:	total: 4.34s	remaining: 27.6s
# 136:	total: 4.38s	remaining: 27.6s
# 137:	total: 4.43s	remaining: 27.7s
# 138:	total: 4.46s	remaining: 27.6s
# 139:	total: 4.5s	remaining: 27.7s
# 140:	total: 4.54s	remaining: 27.7s
# 141:	total: 4.57s	remaining: 27.6s
# 142:	total: 4.6s	remaining: 27.6s
# 143:	total: 4.63s	remaining: 27.5s
# 144:	total: 4.67s	remaining: 27.5s
# 145:	total: 4.72s	remaining: 27.6s
# 146:	total: 4.77s	remaining: 27.7s
# 147:	total: 4.81s	remaining: 27.7s
# 148:	total: 4.85s	remaining: 27.7s
# 149:	total: 4.89s	remaining: 27.7s
# 150:	total: 4.92s	remaining: 27.7s
# 151:	total: 4.96s	remaining: 27.7s
# 152:	total: 4.99s	remaining: 27.6s
# 153:	total: 5.02s	remaining: 27.6s
# 154:	total: 5.06s	remaining: 27.6s
# 155:	total: 5.08s	remaining: 27.5s
# 156:	total: 5.11s	remaining: 27.5s
# 157:	total: 5.15s	remaining: 27.4s
# 158:	total: 5.17s	remaining: 27.4s
# 159:	total: 5.2s	remaining: 27.3s
# 160:	total: 5.23s	remaining: 27.2s
# 161:	total: 5.26s	remaining: 27.2s
# 162:	total: 5.29s	remaining: 27.2s
# 163:	total: 5.32s	remaining: 27.1s
# 164:	total: 5.35s	remaining: 27.1s
# 165:	total: 5.38s	remaining: 27s
# 166:	total: 5.4s	remaining: 27s
# 167:	total: 5.43s	remaining: 26.9s
# 168:	total: 5.46s	remaining: 26.8s
# 169:	total: 5.48s	remaining: 26.8s
# 170:	total: 5.51s	remaining: 26.7s
# 171:	total: 5.54s	remaining: 26.7s
# 172:	total: 5.56s	remaining: 26.6s
# 173:	total: 5.6s	remaining: 26.6s
# 174:	total: 5.62s	remaining: 26.5s
# 175:	total: 5.65s	remaining: 26.4s
# 176:	total: 5.67s	remaining: 26.4s
# 177:	total: 5.7s	remaining: 26.3s
# 178:	total: 5.73s	remaining: 26.3s
# 179:	total: 5.76s	remaining: 26.2s
# 180:	total: 5.78s	remaining: 26.2s
# 181:	total: 5.81s	remaining: 26.1s
# 182:	total: 5.84s	remaining: 26.1s
# 183:	total: 5.87s	remaining: 26s
# 184:	total: 5.9s	remaining: 26s
# 185:	total: 5.93s	remaining: 25.9s
# 186:	total: 5.95s	remaining: 25.9s
# 187:	total: 5.98s	remaining: 25.8s
# 188:	total: 6.01s	remaining: 25.8s
# 189:	total: 6.04s	remaining: 25.8s
# 190:	total: 6.07s	remaining: 25.7s
# 191:	total: 6.1s	remaining: 25.7s
# 192:	total: 6.13s	remaining: 25.6s
# 193:	total: 6.15s	remaining: 25.6s
# 194:	total: 6.18s	remaining: 25.5s
# 195:	total: 6.2s	remaining: 25.4s
# 196:	total: 6.23s	remaining: 25.4s
# 197:	total: 6.31s	remaining: 25.6s
# 198:	total: 6.35s	remaining: 25.5s
# 199:	total: 6.37s	remaining: 25.5s
# 200:	total: 6.4s	remaining: 25.4s
# 201:	total: 6.42s	remaining: 25.4s
# 202:	total: 6.46s	remaining: 25.3s
# 203:	total: 6.49s	remaining: 25.3s
# 204:	total: 6.52s	remaining: 25.3s
# 205:	total: 6.54s	remaining: 25.2s
# 206:	total: 6.57s	remaining: 25.2s
# 207:	total: 6.59s	remaining: 25.1s
# 208:	total: 6.62s	remaining: 25s
# 209:	total: 6.64s	remaining: 25s
# 210:	total: 6.67s	remaining: 25s
# 211:	total: 6.7s	remaining: 24.9s
# 212:	total: 6.73s	remaining: 24.9s
# 213:	total: 6.76s	remaining: 24.8s
# 214:	total: 6.79s	remaining: 24.8s
# 215:	total: 6.82s	remaining: 24.7s
# 216:	total: 6.84s	remaining: 24.7s
# 217:	total: 6.87s	remaining: 24.7s
# 218:	total: 6.9s	remaining: 24.6s
# 219:	total: 6.93s	remaining: 24.6s
# 220:	total: 6.96s	remaining: 24.5s
# 221:	total: 6.99s	remaining: 24.5s
# 222:	total: 7.01s	remaining: 24.4s
# 223:	total: 7.04s	remaining: 24.4s
# 224:	total: 7.07s	remaining: 24.3s
# 225:	total: 7.11s	remaining: 24.3s
# 226:	total: 7.13s	remaining: 24.3s
# 227:	total: 7.15s	remaining: 24.2s
# 228:	total: 7.18s	remaining: 24.2s
# 229:	total: 7.21s	remaining: 24.1s
# 230:	total: 7.23s	remaining: 24.1s
# 231:	total: 7.26s	remaining: 24s
# 232:	total: 7.29s	remaining: 24s
# 233:	total: 7.33s	remaining: 24s
# 234:	total: 7.36s	remaining: 23.9s
# 235:	total: 7.38s	remaining: 23.9s
# 236:	total: 7.41s	remaining: 23.8s
# 237:	total: 7.43s	remaining: 23.8s
# 238:	total: 7.46s	remaining: 23.7s
# 239:	total: 7.48s	remaining: 23.7s
# 240:	total: 7.52s	remaining: 23.7s
# 241:	total: 7.55s	remaining: 23.7s
# 242:	total: 7.59s	remaining: 23.6s
# 243:	total: 7.61s	remaining: 23.6s
# 244:	total: 7.64s	remaining: 23.5s
# 245:	total: 7.66s	remaining: 23.5s
# 246:	total: 7.69s	remaining: 23.4s
# 247:	total: 7.71s	remaining: 23.4s
# 248:	total: 7.74s	remaining: 23.4s
# 249:	total: 7.78s	remaining: 23.3s
# 250:	total: 7.8s	remaining: 23.3s
# 251:	total: 7.83s	remaining: 23.2s
# 252:	total: 7.86s	remaining: 23.2s
# 253:	total: 7.88s	remaining: 23.1s
# 254:	total: 7.91s	remaining: 23.1s
# 255:	total: 7.93s	remaining: 23.1s
# 256:	total: 7.96s	remaining: 23s
# 257:	total: 7.99s	remaining: 23s
# 258:	total: 8.02s	remaining: 22.9s
# 259:	total: 8.04s	remaining: 22.9s
# 260:	total: 8.07s	remaining: 22.8s
# 261:	total: 8.09s	remaining: 22.8s
# 262:	total: 8.12s	remaining: 22.8s
# 263:	total: 8.15s	remaining: 22.7s
# 264:	total: 8.19s	remaining: 22.7s
# 265:	total: 8.21s	remaining: 22.7s
# 266:	total: 8.24s	remaining: 22.6s
# 267:	total: 8.26s	remaining: 22.6s
# 268:	total: 8.29s	remaining: 22.5s
# 269:	total: 8.32s	remaining: 22.5s
# 270:	total: 8.34s	remaining: 22.4s
# 271:	total: 8.37s	remaining: 22.4s
# 272:	total: 8.4s	remaining: 22.4s
# 273:	total: 8.43s	remaining: 22.3s
# 274:	total: 8.45s	remaining: 22.3s
# 275:	total: 8.48s	remaining: 22.2s
# 276:	total: 8.51s	remaining: 22.2s
# 277:	total: 8.53s	remaining: 22.2s
# 278:	total: 8.56s	remaining: 22.1s
# 279:	total: 8.59s	remaining: 22.1s
# 280:	total: 8.62s	remaining: 22.1s
# 281:	total: 8.65s	remaining: 22s
# 282:	total: 8.67s	remaining: 22s
# 283:	total: 8.7s	remaining: 21.9s
# 284:	total: 8.72s	remaining: 21.9s
# 285:	total: 8.76s	remaining: 21.9s
# 286:	total: 8.78s	remaining: 21.8s
# 287:	total: 8.81s	remaining: 21.8s
# 288:	total: 8.84s	remaining: 21.7s
# 289:	total: 8.86s	remaining: 21.7s
# 290:	total: 8.89s	remaining: 21.7s
# 291:	total: 8.92s	remaining: 21.6s
# 292:	total: 8.94s	remaining: 21.6s
# 293:	total: 8.97s	remaining: 21.5s
# 294:	total: 9s	remaining: 21.5s
# 295:	total: 9.03s	remaining: 21.5s
# 296:	total: 9.06s	remaining: 21.4s
# 297:	total: 9.09s	remaining: 21.4s
# 298:	total: 9.11s	remaining: 21.4s
# 299:	total: 9.14s	remaining: 21.3s
# 300:	total: 9.17s	remaining: 21.3s
# 301:	total: 9.19s	remaining: 21.2s
# 302:	total: 9.22s	remaining: 21.2s
# 303:	total: 9.25s	remaining: 21.2s
# 304:	total: 9.28s	remaining: 21.1s
# 305:	total: 9.31s	remaining: 21.1s
# 306:	total: 9.33s	remaining: 21.1s
# 307:	total: 9.36s	remaining: 21s
# 308:	total: 9.39s	remaining: 21s
# 309:	total: 9.41s	remaining: 20.9s
# 310:	total: 9.44s	remaining: 20.9s
# 311:	total: 9.46s	remaining: 20.9s
# 312:	total: 9.5s	remaining: 20.8s
# 313:	total: 9.52s	remaining: 20.8s
# 314:	total: 9.55s	remaining: 20.8s
# 315:	total: 9.58s	remaining: 20.7s
# 316:	total: 9.61s	remaining: 20.7s
# 317:	total: 9.64s	remaining: 20.7s
# 318:	total: 9.66s	remaining: 20.6s
# 319:	total: 9.72s	remaining: 20.7s
# 320:	total: 9.76s	remaining: 20.6s
# 321:	total: 9.79s	remaining: 20.6s
# 322:	total: 9.81s	remaining: 20.6s
# 323:	total: 9.84s	remaining: 20.5s
# 324:	total: 9.86s	remaining: 20.5s
# 325:	total: 9.89s	remaining: 20.4s
# 326:	total: 9.91s	remaining: 20.4s
# 327:	total: 9.94s	remaining: 20.4s
# 328:	total: 9.97s	remaining: 20.3s
# 329:	total: 9.99s	remaining: 20.3s
# 330:	total: 10s	remaining: 20.3s
# 331:	total: 10s	remaining: 20.2s
# 332:	total: 10.1s	remaining: 20.2s
# 333:	total: 10.1s	remaining: 20.1s
# 334:	total: 10.1s	remaining: 20.1s
# 335:	total: 10.1s	remaining: 20.1s
# 336:	total: 10.2s	remaining: 20s
# 337:	total: 10.2s	remaining: 20s
# 338:	total: 10.2s	remaining: 20s
# 339:	total: 10.3s	remaining: 19.9s
# 340:	total: 10.3s	remaining: 19.9s
# 341:	total: 10.3s	remaining: 19.9s
# 342:	total: 10.3s	remaining: 19.8s
# 343:	total: 10.4s	remaining: 19.8s
# 344:	total: 10.4s	remaining: 19.8s
# 345:	total: 10.4s	remaining: 19.7s
# 346:	total: 10.5s	remaining: 19.7s
# 347:	total: 10.5s	remaining: 19.6s
# 348:	total: 10.5s	remaining: 19.6s
# 349:	total: 10.5s	remaining: 19.6s
# 350:	total: 10.6s	remaining: 19.5s
# 351:	total: 10.6s	remaining: 19.5s
# 352:	total: 10.6s	remaining: 19.5s
# 353:	total: 10.7s	remaining: 19.5s
# 354:	total: 10.7s	remaining: 19.4s
# 355:	total: 10.7s	remaining: 19.4s
# 356:	total: 10.8s	remaining: 19.4s
# 357:	total: 10.8s	remaining: 19.4s
# 358:	total: 10.8s	remaining: 19.3s
# 359:	total: 10.8s	remaining: 19.3s
# 360:	total: 10.9s	remaining: 19.3s
# 361:	total: 10.9s	remaining: 19.2s
# 362:	total: 10.9s	remaining: 19.2s
# 363:	total: 11s	remaining: 19.1s
# 364:	total: 11s	remaining: 19.1s
# 365:	total: 11s	remaining: 19.1s
# 366:	total: 11s	remaining: 19s
# 367:	total: 11.1s	remaining: 19s
# 368:	total: 11.1s	remaining: 19s
# 369:	total: 11.1s	remaining: 18.9s
# 370:	total: 11.2s	remaining: 18.9s
# 371:	total: 11.2s	remaining: 18.9s
# 372:	total: 11.2s	remaining: 18.8s
# 373:	total: 11.2s	remaining: 18.8s
# 374:	total: 11.3s	remaining: 18.8s
# 375:	total: 11.3s	remaining: 18.7s
# 376:	total: 11.3s	remaining: 18.7s
# 377:	total: 11.3s	remaining: 18.7s
# 378:	total: 11.4s	remaining: 18.6s
# 379:	total: 11.4s	remaining: 18.6s
# 380:	total: 11.4s	remaining: 18.6s
# 381:	total: 11.5s	remaining: 18.5s
# 382:	total: 11.5s	remaining: 18.5s
# 383:	total: 11.5s	remaining: 18.5s
# 384:	total: 11.5s	remaining: 18.4s
# 385:	total: 11.6s	remaining: 18.4s
# 386:	total: 11.6s	remaining: 18.4s
# 387:	total: 11.6s	remaining: 18.3s
# 388:	total: 11.6s	remaining: 18.3s
# 389:	total: 11.7s	remaining: 18.3s
# 390:	total: 11.7s	remaining: 18.2s
# 391:	total: 11.7s	remaining: 18.2s
# 392:	total: 11.7s	remaining: 18.1s
# 393:	total: 11.8s	remaining: 18.1s
# 394:	total: 11.8s	remaining: 18.1s
# 395:	total: 11.8s	remaining: 18s
# 396:	total: 11.9s	remaining: 18s
# 397:	total: 11.9s	remaining: 18s
# 398:	total: 11.9s	remaining: 17.9s
# 399:	total: 11.9s	remaining: 17.9s
# 400:	total: 12s	remaining: 17.9s
# 401:	total: 12s	remaining: 17.8s
# 402:	total: 12s	remaining: 17.8s
# 403:	total: 12s	remaining: 17.8s
# 404:	total: 12.1s	remaining: 17.7s
# 405:	total: 12.1s	remaining: 17.7s
# 406:	total: 12.1s	remaining: 17.7s
# 407:	total: 12.2s	remaining: 17.6s
# 408:	total: 12.2s	remaining: 17.6s
# 409:	total: 12.2s	remaining: 17.6s
# 410:	total: 12.2s	remaining: 17.5s
# 411:	total: 12.3s	remaining: 17.5s
# 412:	total: 12.3s	remaining: 17.5s
# 413:	total: 12.3s	remaining: 17.4s
# 414:	total: 12.3s	remaining: 17.4s
# 415:	total: 12.4s	remaining: 17.4s
# 416:	total: 12.4s	remaining: 17.3s
# 417:	total: 12.4s	remaining: 17.3s
# 418:	total: 12.5s	remaining: 17.3s
# 419:	total: 12.5s	remaining: 17.2s
# 420:	total: 12.5s	remaining: 17.2s
# 421:	total: 12.5s	remaining: 17.2s
# 422:	total: 12.6s	remaining: 17.1s
# 423:	total: 12.6s	remaining: 17.1s
# 424:	total: 12.6s	remaining: 17.1s
# 425:	total: 12.6s	remaining: 17s
# 426:	total: 12.7s	remaining: 17s
# 427:	total: 12.7s	remaining: 17s
# 428:	total: 12.7s	remaining: 16.9s
# 429:	total: 12.8s	remaining: 16.9s
# 430:	total: 12.8s	remaining: 16.9s
# 431:	total: 12.8s	remaining: 16.8s
# 432:	total: 12.8s	remaining: 16.8s
# 433:	total: 12.9s	remaining: 16.8s
# 434:	total: 12.9s	remaining: 16.8s
# 435:	total: 12.9s	remaining: 16.7s
# 436:	total: 13s	remaining: 16.7s
# 437:	total: 13s	remaining: 16.7s
# 438:	total: 13s	remaining: 16.6s
# 439:	total: 13s	remaining: 16.6s
# 440:	total: 13.1s	remaining: 16.6s
# 441:	total: 13.1s	remaining: 16.5s
# 442:	total: 13.1s	remaining: 16.5s
# 443:	total: 13.1s	remaining: 16.5s
# 444:	total: 13.2s	remaining: 16.4s
# 445:	total: 13.2s	remaining: 16.4s
# 446:	total: 13.2s	remaining: 16.4s
# 447:	total: 13.3s	remaining: 16.3s
# 448:	total: 13.3s	remaining: 16.3s
# 449:	total: 13.3s	remaining: 16.3s
# 450:	total: 13.3s	remaining: 16.2s
# 451:	total: 13.4s	remaining: 16.2s
# 452:	total: 13.4s	remaining: 16.2s
# 453:	total: 13.4s	remaining: 16.1s
# 454:	total: 13.4s	remaining: 16.1s
# 455:	total: 13.5s	remaining: 16.1s
# 456:	total: 13.5s	remaining: 16s
# 457:	total: 13.5s	remaining: 16s
# 458:	total: 13.6s	remaining: 16s
# 459:	total: 13.6s	remaining: 15.9s
# 460:	total: 13.6s	remaining: 15.9s
# 461:	total: 13.6s	remaining: 15.9s
# 462:	total: 13.7s	remaining: 15.8s
# 463:	total: 13.7s	remaining: 15.8s
# 464:	total: 13.7s	remaining: 15.8s
# 465:	total: 13.7s	remaining: 15.8s
# 466:	total: 13.8s	remaining: 15.7s
# 467:	total: 13.8s	remaining: 15.7s
# 468:	total: 13.8s	remaining: 15.7s
# 469:	total: 13.9s	remaining: 15.6s
# 470:	total: 13.9s	remaining: 15.6s
# 471:	total: 13.9s	remaining: 15.6s
# 472:	total: 13.9s	remaining: 15.5s
# 473:	total: 14s	remaining: 15.5s
# 474:	total: 14s	remaining: 15.5s
# 475:	total: 14s	remaining: 15.4s
# 476:	total: 14s	remaining: 15.4s
# 477:	total: 14.1s	remaining: 15.3s
# 478:	total: 14.1s	remaining: 15.3s
# 479:	total: 14.1s	remaining: 15.3s
# 480:	total: 14.1s	remaining: 15.2s
# 481:	total: 14.1s	remaining: 15.2s
# 482:	total: 14.2s	remaining: 15.2s
# 483:	total: 14.2s	remaining: 15.1s
# 484:	total: 14.2s	remaining: 15.1s
# 485:	total: 14.2s	remaining: 15.1s
# 486:	total: 14.3s	remaining: 15s
# 487:	total: 14.3s	remaining: 15s
# 488:	total: 14.3s	remaining: 14.9s
# 489:	total: 14.3s	remaining: 14.9s
# 490:	total: 14.4s	remaining: 14.9s
# 491:	total: 14.4s	remaining: 14.8s
# 492:	total: 14.4s	remaining: 14.8s
# 493:	total: 14.4s	remaining: 14.8s
# 494:	total: 14.4s	remaining: 14.7s
# 495:	total: 14.5s	remaining: 14.7s
# 496:	total: 14.5s	remaining: 14.7s
# 497:	total: 14.5s	remaining: 14.6s
# 498:	total: 14.5s	remaining: 14.6s
# 499:	total: 14.6s	remaining: 14.6s
# 500:	total: 14.6s	remaining: 14.5s
# 501:	total: 14.6s	remaining: 14.5s
# 502:	total: 14.6s	remaining: 14.5s
# 503:	total: 14.7s	remaining: 14.4s
# 504:	total: 14.7s	remaining: 14.4s
# 505:	total: 14.7s	remaining: 14.4s
# 506:	total: 14.7s	remaining: 14.3s
# 507:	total: 14.8s	remaining: 14.3s
# 508:	total: 14.8s	remaining: 14.3s
# 509:	total: 14.8s	remaining: 14.2s
# 510:	total: 14.8s	remaining: 14.2s
# 511:	total: 14.9s	remaining: 14.2s
# 512:	total: 14.9s	remaining: 14.1s
# 513:	total: 14.9s	remaining: 14.1s
# 514:	total: 14.9s	remaining: 14.1s
# 515:	total: 15s	remaining: 14s
# 516:	total: 15s	remaining: 14s
# 517:	total: 15s	remaining: 14s
# 518:	total: 15.1s	remaining: 13.9s
# 519:	total: 15.1s	remaining: 13.9s
# 520:	total: 15.1s	remaining: 13.9s
# 521:	total: 15.1s	remaining: 13.8s
# 522:	total: 15.1s	remaining: 13.8s
# 523:	total: 15.2s	remaining: 13.8s
# 524:	total: 15.2s	remaining: 13.7s
# 525:	total: 15.2s	remaining: 13.7s
# 526:	total: 15.2s	remaining: 13.7s
# 527:	total: 15.3s	remaining: 13.7s
# 528:	total: 15.3s	remaining: 13.6s
# 529:	total: 15.3s	remaining: 13.6s
# 530:	total: 15.3s	remaining: 13.6s
# 531:	total: 15.4s	remaining: 13.5s
# 532:	total: 15.4s	remaining: 13.5s
# 533:	total: 15.4s	remaining: 13.5s
# 534:	total: 15.4s	remaining: 13.4s
# 535:	total: 15.5s	remaining: 13.4s
# 536:	total: 15.5s	remaining: 13.3s
# 537:	total: 15.5s	remaining: 13.3s
# 538:	total: 15.5s	remaining: 13.3s
# 539:	total: 15.6s	remaining: 13.2s
# 540:	total: 15.6s	remaining: 13.2s
# 541:	total: 15.6s	remaining: 13.2s
# 542:	total: 15.6s	remaining: 13.1s
# 543:	total: 15.6s	remaining: 13.1s
# 544:	total: 15.7s	remaining: 13.1s
# 545:	total: 15.7s	remaining: 13s
# 546:	total: 15.7s	remaining: 13s
# 547:	total: 15.7s	remaining: 13s
# 548:	total: 15.8s	remaining: 12.9s
# 549:	total: 15.8s	remaining: 12.9s
# 550:	total: 15.8s	remaining: 12.9s
# 551:	total: 15.8s	remaining: 12.9s
# 552:	total: 15.9s	remaining: 12.8s
# 553:	total: 15.9s	remaining: 12.8s
# 554:	total: 15.9s	remaining: 12.8s
# 555:	total: 15.9s	remaining: 12.7s
# 556:	total: 16s	remaining: 12.7s
# 557:	total: 16s	remaining: 12.7s
# 558:	total: 16s	remaining: 12.6s
# 559:	total: 16s	remaining: 12.6s
# 560:	total: 16.1s	remaining: 12.6s
# 561:	total: 16.1s	remaining: 12.5s
# 562:	total: 16.1s	remaining: 12.5s
# 563:	total: 16.1s	remaining: 12.5s
# 564:	total: 16.1s	remaining: 12.4s
# 565:	total: 16.2s	remaining: 12.4s
# 566:	total: 16.2s	remaining: 12.4s
# 567:	total: 16.2s	remaining: 12.3s
# 568:	total: 16.2s	remaining: 12.3s
# 569:	total: 16.3s	remaining: 12.3s
# 570:	total: 16.3s	remaining: 12.2s
# 571:	total: 16.3s	remaining: 12.2s
# 572:	total: 16.3s	remaining: 12.2s
# 573:	total: 16.4s	remaining: 12.1s
# 574:	total: 16.4s	remaining: 12.1s
# 575:	total: 16.4s	remaining: 12.1s
# 576:	total: 16.4s	remaining: 12s
# 577:	total: 16.4s	remaining: 12s
# 578:	total: 16.5s	remaining: 12s
# 579:	total: 16.5s	remaining: 11.9s
# 580:	total: 16.5s	remaining: 11.9s
# 581:	total: 16.5s	remaining: 11.9s
# 582:	total: 16.6s	remaining: 11.8s
# 583:	total: 16.6s	remaining: 11.8s
# 584:	total: 16.6s	remaining: 11.8s
# 585:	total: 16.6s	remaining: 11.7s
# 586:	total: 16.7s	remaining: 11.7s
# 587:	total: 16.7s	remaining: 11.7s
# 588:	total: 16.7s	remaining: 11.7s
# 589:	total: 16.7s	remaining: 11.6s
# 590:	total: 16.8s	remaining: 11.6s
# 591:	total: 16.8s	remaining: 11.6s
# 592:	total: 16.8s	remaining: 11.5s
# 593:	total: 16.8s	remaining: 11.5s
# 594:	total: 16.9s	remaining: 11.5s
# 595:	total: 16.9s	remaining: 11.4s
# 596:	total: 16.9s	remaining: 11.4s
# 597:	total: 16.9s	remaining: 11.4s
# 598:	total: 16.9s	remaining: 11.3s
# 599:	total: 17s	remaining: 11.3s
# 600:	total: 17s	remaining: 11.3s
# 601:	total: 17s	remaining: 11.2s
# 602:	total: 17s	remaining: 11.2s
# 603:	total: 17.1s	remaining: 11.2s
# 604:	total: 17.1s	remaining: 11.2s
# 605:	total: 17.1s	remaining: 11.1s
# 606:	total: 17.1s	remaining: 11.1s
# 607:	total: 17.2s	remaining: 11.1s
# 608:	total: 17.2s	remaining: 11s
# 609:	total: 17.2s	remaining: 11s
# 610:	total: 17.2s	remaining: 11s
# 611:	total: 17.2s	remaining: 10.9s
# 612:	total: 17.3s	remaining: 10.9s
# 613:	total: 17.3s	remaining: 10.9s
# 614:	total: 17.3s	remaining: 10.8s
# 615:	total: 17.3s	remaining: 10.8s
# 616:	total: 17.4s	remaining: 10.8s
# 617:	total: 17.4s	remaining: 10.8s
# 618:	total: 17.4s	remaining: 10.7s
# 619:	total: 17.5s	remaining: 10.7s
# 620:	total: 17.5s	remaining: 10.7s
# 621:	total: 17.5s	remaining: 10.6s
# 622:	total: 17.5s	remaining: 10.6s
# 623:	total: 17.6s	remaining: 10.6s
# 624:	total: 17.6s	remaining: 10.5s
# 625:	total: 17.6s	remaining: 10.5s
# 626:	total: 17.6s	remaining: 10.5s
# 627:	total: 17.7s	remaining: 10.5s
# 628:	total: 17.7s	remaining: 10.4s
# 629:	total: 17.7s	remaining: 10.4s
# 630:	total: 17.7s	remaining: 10.4s
# 631:	total: 17.7s	remaining: 10.3s
# 632:	total: 17.8s	remaining: 10.3s
# 633:	total: 17.8s	remaining: 10.3s
# 634:	total: 17.8s	remaining: 10.2s
# 635:	total: 17.8s	remaining: 10.2s
# 636:	total: 17.9s	remaining: 10.2s
# 637:	total: 17.9s	remaining: 10.1s
# 638:	total: 17.9s	remaining: 10.1s
# 639:	total: 17.9s	remaining: 10.1s
# 640:	total: 18s	remaining: 10.1s
# 641:	total: 18s	remaining: 10s
# 642:	total: 18s	remaining: 10s
# 643:	total: 18s	remaining: 9.97s
# 644:	total: 18.1s	remaining: 9.94s
# 645:	total: 18.1s	remaining: 9.91s
# 646:	total: 18.1s	remaining: 9.88s
# 647:	total: 18.1s	remaining: 9.85s
# 648:	total: 18.2s	remaining: 9.82s
# 649:	total: 18.2s	remaining: 9.79s
# 650:	total: 18.2s	remaining: 9.76s
# 651:	total: 18.2s	remaining: 9.73s
# 652:	total: 18.3s	remaining: 9.7s
# 653:	total: 18.3s	remaining: 9.67s
# 654:	total: 18.3s	remaining: 9.64s
# 655:	total: 18.3s	remaining: 9.61s
# 656:	total: 18.3s	remaining: 9.58s
# 657:	total: 18.4s	remaining: 9.55s
# 658:	total: 18.4s	remaining: 9.52s
# 659:	total: 18.4s	remaining: 9.49s
# 660:	total: 18.4s	remaining: 9.46s
# 661:	total: 18.5s	remaining: 9.43s
# 662:	total: 18.5s	remaining: 9.4s
# 663:	total: 18.5s	remaining: 9.37s
# 664:	total: 18.5s	remaining: 9.34s
# 665:	total: 18.6s	remaining: 9.31s
# 666:	total: 18.6s	remaining: 9.28s
# 667:	total: 18.6s	remaining: 9.25s
# 668:	total: 18.6s	remaining: 9.22s
# 669:	total: 18.7s	remaining: 9.19s
# 670:	total: 18.7s	remaining: 9.16s
# 671:	total: 18.7s	remaining: 9.13s
# 672:	total: 18.7s	remaining: 9.1s
# 673:	total: 18.7s	remaining: 9.07s
# 674:	total: 18.8s	remaining: 9.04s
# 675:	total: 18.8s	remaining: 9.01s
# 676:	total: 18.8s	remaining: 8.98s
# 677:	total: 18.8s	remaining: 8.95s
# 678:	total: 18.9s	remaining: 8.92s
# 679:	total: 18.9s	remaining: 8.89s
# 680:	total: 18.9s	remaining: 8.86s
# 681:	total: 18.9s	remaining: 8.83s
# 682:	total: 19s	remaining: 8.8s
# 683:	total: 19s	remaining: 8.77s
# 684:	total: 19s	remaining: 8.74s
# 685:	total: 19s	remaining: 8.71s
# 686:	total: 19.1s	remaining: 8.68s
# 687:	total: 19.1s	remaining: 8.65s
# 688:	total: 19.1s	remaining: 8.62s
# 689:	total: 19.1s	remaining: 8.59s
# 690:	total: 19.1s	remaining: 8.56s
# 691:	total: 19.2s	remaining: 8.53s
# 692:	total: 19.2s	remaining: 8.5s
# 693:	total: 19.2s	remaining: 8.47s
# 694:	total: 19.2s	remaining: 8.45s
# 695:	total: 19.3s	remaining: 8.41s
# 696:	total: 19.3s	remaining: 8.38s
# 697:	total: 19.3s	remaining: 8.36s
# 698:	total: 19.3s	remaining: 8.33s
# 699:	total: 19.4s	remaining: 8.3s
# 700:	total: 19.4s	remaining: 8.27s
# 701:	total: 19.4s	remaining: 8.24s
# 702:	total: 19.4s	remaining: 8.21s
# 703:	total: 19.5s	remaining: 8.18s
# 704:	total: 19.5s	remaining: 8.15s
# 705:	total: 19.5s	remaining: 8.12s
# 706:	total: 19.5s	remaining: 8.09s
# 707:	total: 19.6s	remaining: 8.06s
# 708:	total: 19.6s	remaining: 8.04s
# 709:	total: 19.6s	remaining: 8.01s
# 710:	total: 19.6s	remaining: 7.98s
# 711:	total: 19.7s	remaining: 7.95s
# 712:	total: 19.7s	remaining: 7.92s
# 713:	total: 19.7s	remaining: 7.89s
# 714:	total: 19.7s	remaining: 7.87s
# 715:	total: 19.8s	remaining: 7.84s
# 716:	total: 19.8s	remaining: 7.81s
# 717:	total: 19.8s	remaining: 7.78s
# 718:	total: 19.8s	remaining: 7.75s
# 719:	total: 19.9s	remaining: 7.75s
# 720:	total: 19.9s	remaining: 7.72s
# 721:	total: 20s	remaining: 7.69s
# 722:	total: 20s	remaining: 7.66s
# 723:	total: 20s	remaining: 7.63s
# 724:	total: 20s	remaining: 7.6s
# 725:	total: 20.1s	remaining: 7.58s
# 726:	total: 20.1s	remaining: 7.54s
# 727:	total: 20.1s	remaining: 7.52s
# 728:	total: 20.1s	remaining: 7.49s
# 729:	total: 20.2s	remaining: 7.46s
# 730:	total: 20.2s	remaining: 7.43s
# 731:	total: 20.2s	remaining: 7.4s
# 732:	total: 20.2s	remaining: 7.37s
# 733:	total: 20.3s	remaining: 7.34s
# 734:	total: 20.3s	remaining: 7.32s
# 735:	total: 20.3s	remaining: 7.29s
# 736:	total: 20.3s	remaining: 7.26s
# 737:	total: 20.4s	remaining: 7.23s
# 738:	total: 20.4s	remaining: 7.2s
# 739:	total: 20.4s	remaining: 7.17s
# 740:	total: 20.4s	remaining: 7.14s
# 741:	total: 20.5s	remaining: 7.11s
# 742:	total: 20.5s	remaining: 7.08s
# 743:	total: 20.5s	remaining: 7.05s
# 744:	total: 20.5s	remaining: 7.03s
# 745:	total: 20.6s	remaining: 7s
# 746:	total: 20.6s	remaining: 6.97s
# 747:	total: 20.6s	remaining: 6.94s
# 748:	total: 20.6s	remaining: 6.91s
# 749:	total: 20.6s	remaining: 6.88s
# 750:	total: 20.7s	remaining: 6.85s
# 751:	total: 20.7s	remaining: 6.83s
# 752:	total: 20.7s	remaining: 6.8s
# 753:	total: 20.7s	remaining: 6.77s
# 754:	total: 20.8s	remaining: 6.74s
# 755:	total: 20.8s	remaining: 6.71s
# 756:	total: 20.8s	remaining: 6.68s
# 757:	total: 20.8s	remaining: 6.65s
# 758:	total: 20.9s	remaining: 6.62s
# 759:	total: 20.9s	remaining: 6.6s
# 760:	total: 20.9s	remaining: 6.57s
# 761:	total: 20.9s	remaining: 6.54s
# 762:	total: 21s	remaining: 6.51s
# 763:	total: 21s	remaining: 6.48s
# 764:	total: 21s	remaining: 6.45s
# 765:	total: 21s	remaining: 6.42s
# 766:	total: 21s	remaining: 6.39s
# 767:	total: 21.1s	remaining: 6.37s
# 768:	total: 21.1s	remaining: 6.34s
# 769:	total: 21.1s	remaining: 6.31s
# 770:	total: 21.1s	remaining: 6.28s
# 771:	total: 21.2s	remaining: 6.25s
# 772:	total: 21.2s	remaining: 6.22s
# 773:	total: 21.2s	remaining: 6.2s
# 774:	total: 21.2s	remaining: 6.17s
# 775:	total: 21.3s	remaining: 6.14s
# 776:	total: 21.3s	remaining: 6.11s
# 777:	total: 21.3s	remaining: 6.08s
# 778:	total: 21.3s	remaining: 6.05s
# 779:	total: 21.4s	remaining: 6.03s
# 780:	total: 21.4s	remaining: 6s
# 781:	total: 21.4s	remaining: 5.97s
# 782:	total: 21.5s	remaining: 5.95s
# 783:	total: 21.5s	remaining: 5.92s
# 784:	total: 21.5s	remaining: 5.89s
# 785:	total: 21.5s	remaining: 5.86s
# 786:	total: 21.6s	remaining: 5.83s
# 787:	total: 21.6s	remaining: 5.81s
# 788:	total: 21.6s	remaining: 5.78s
# 789:	total: 21.6s	remaining: 5.75s
# 790:	total: 21.7s	remaining: 5.72s
# 791:	total: 21.7s	remaining: 5.7s
# 792:	total: 21.7s	remaining: 5.67s
# 793:	total: 21.7s	remaining: 5.64s
# 794:	total: 21.8s	remaining: 5.61s
# 795:	total: 21.8s	remaining: 5.58s
# 796:	total: 21.8s	remaining: 5.55s
# 797:	total: 21.8s	remaining: 5.52s
# 798:	total: 21.9s	remaining: 5.5s
# 799:	total: 21.9s	remaining: 5.47s
# 800:	total: 21.9s	remaining: 5.44s
# 801:	total: 21.9s	remaining: 5.41s
# 802:	total: 22s	remaining: 5.38s
# 803:	total: 22s	remaining: 5.36s
# 804:	total: 22s	remaining: 5.33s
# 805:	total: 22s	remaining: 5.3s
# 806:	total: 22s	remaining: 5.27s
# 807:	total: 22.1s	remaining: 5.24s
# 808:	total: 22.1s	remaining: 5.21s
# 809:	total: 22.1s	remaining: 5.19s
# 810:	total: 22.1s	remaining: 5.16s
# 811:	total: 22.2s	remaining: 5.13s
# 812:	total: 22.2s	remaining: 5.1s
# 813:	total: 22.2s	remaining: 5.08s
# 814:	total: 22.2s	remaining: 5.05s
# 815:	total: 22.3s	remaining: 5.02s
# 816:	total: 22.3s	remaining: 4.99s
# 817:	total: 22.3s	remaining: 4.96s
# 818:	total: 22.3s	remaining: 4.93s
# 819:	total: 22.4s	remaining: 4.91s
# 820:	total: 22.4s	remaining: 4.88s
# 821:	total: 22.4s	remaining: 4.85s
# 822:	total: 22.4s	remaining: 4.82s
# 823:	total: 22.5s	remaining: 4.79s
# 824:	total: 22.5s	remaining: 4.77s
# 825:	total: 22.5s	remaining: 4.74s
# 826:	total: 22.5s	remaining: 4.71s
# 827:	total: 22.5s	remaining: 4.68s
# 828:	total: 22.6s	remaining: 4.66s
# 829:	total: 22.6s	remaining: 4.63s
# 830:	total: 22.6s	remaining: 4.6s
# 831:	total: 22.6s	remaining: 4.57s
# 832:	total: 22.7s	remaining: 4.54s
# 833:	total: 22.7s	remaining: 4.52s
# 834:	total: 22.7s	remaining: 4.49s
# 835:	total: 22.7s	remaining: 4.46s
# 836:	total: 22.8s	remaining: 4.43s
# 837:	total: 22.8s	remaining: 4.4s
# 838:	total: 22.8s	remaining: 4.38s
# 839:	total: 22.8s	remaining: 4.35s
# 840:	total: 22.9s	remaining: 4.32s
# 841:	total: 22.9s	remaining: 4.29s
# 842:	total: 22.9s	remaining: 4.27s
# 843:	total: 22.9s	remaining: 4.24s
# 844:	total: 23s	remaining: 4.21s
# 845:	total: 23s	remaining: 4.18s
# 846:	total: 23s	remaining: 4.16s
# 847:	total: 23s	remaining: 4.13s
# 848:	total: 23.1s	remaining: 4.1s
# 849:	total: 23.1s	remaining: 4.07s
# 850:	total: 23.1s	remaining: 4.05s
# 851:	total: 23.1s	remaining: 4.02s
# 852:	total: 23.2s	remaining: 3.99s
# 853:	total: 23.2s	remaining: 3.96s
# 854:	total: 23.2s	remaining: 3.94s
# 855:	total: 23.2s	remaining: 3.91s
# 856:	total: 23.2s	remaining: 3.88s
# 857:	total: 23.3s	remaining: 3.85s
# 858:	total: 23.3s	remaining: 3.82s
# 859:	total: 23.3s	remaining: 3.8s
# 860:	total: 23.3s	remaining: 3.77s
# 861:	total: 23.4s	remaining: 3.74s
# 862:	total: 23.4s	remaining: 3.71s
# 863:	total: 23.4s	remaining: 3.69s
# 864:	total: 23.4s	remaining: 3.66s
# 865:	total: 23.5s	remaining: 3.63s
# 866:	total: 23.5s	remaining: 3.6s
# 867:	total: 23.5s	remaining: 3.58s
# 868:	total: 23.5s	remaining: 3.55s
# 869:	total: 23.6s	remaining: 3.52s
# 870:	total: 23.6s	remaining: 3.49s
# 871:	total: 23.6s	remaining: 3.46s
# 872:	total: 23.6s	remaining: 3.44s
# 873:	total: 23.7s	remaining: 3.41s
# 874:	total: 23.7s	remaining: 3.38s
# 875:	total: 23.7s	remaining: 3.35s
# 876:	total: 23.7s	remaining: 3.33s
# 877:	total: 23.8s	remaining: 3.3s
# 878:	total: 23.8s	remaining: 3.27s
# 879:	total: 23.8s	remaining: 3.25s
# 880:	total: 23.8s	remaining: 3.22s
# 881:	total: 23.8s	remaining: 3.19s
# 882:	total: 23.9s	remaining: 3.16s
# 883:	total: 23.9s	remaining: 3.13s
# 884:	total: 23.9s	remaining: 3.11s
# 885:	total: 23.9s	remaining: 3.08s
# 886:	total: 24s	remaining: 3.05s
# 887:	total: 24s	remaining: 3.02s
# 888:	total: 24s	remaining: 3s
# 889:	total: 24s	remaining: 2.97s
# 890:	total: 24.1s	remaining: 2.94s
# 891:	total: 24.1s	remaining: 2.92s
# 892:	total: 24.1s	remaining: 2.89s
# 893:	total: 24.1s	remaining: 2.86s
# 894:	total: 24.2s	remaining: 2.83s
# 895:	total: 24.2s	remaining: 2.81s
# 896:	total: 24.2s	remaining: 2.78s
# 897:	total: 24.2s	remaining: 2.75s
# 898:	total: 24.2s	remaining: 2.72s
# 899:	total: 24.3s	remaining: 2.7s
# 900:	total: 24.3s	remaining: 2.67s
# 901:	total: 24.3s	remaining: 2.64s
# 902:	total: 24.3s	remaining: 2.62s
# 903:	total: 24.4s	remaining: 2.59s
# 904:	total: 24.4s	remaining: 2.56s
# 905:	total: 24.4s	remaining: 2.53s
# 906:	total: 24.4s	remaining: 2.5s
# 907:	total: 24.5s	remaining: 2.48s
# 908:	total: 24.5s	remaining: 2.45s
# 909:	total: 24.5s	remaining: 2.42s
# 910:	total: 24.5s	remaining: 2.4s
# 911:	total: 24.6s	remaining: 2.37s
# 912:	total: 24.6s	remaining: 2.34s
# 913:	total: 24.6s	remaining: 2.31s
# 914:	total: 24.6s	remaining: 2.29s
# 915:	total: 24.6s	remaining: 2.26s
# 916:	total: 24.7s	remaining: 2.23s
# 917:	total: 24.7s	remaining: 2.21s
# 918:	total: 24.7s	remaining: 2.18s
# 919:	total: 24.7s	remaining: 2.15s
# 920:	total: 24.8s	remaining: 2.13s
# 921:	total: 24.8s	remaining: 2.1s
# 922:	total: 24.8s	remaining: 2.07s
# 923:	total: 24.8s	remaining: 2.04s
# 924:	total: 24.9s	remaining: 2.02s
# 925:	total: 24.9s	remaining: 1.99s
# 926:	total: 24.9s	remaining: 1.96s
# 927:	total: 24.9s	remaining: 1.93s
# 928:	total: 25s	remaining: 1.91s
# 929:	total: 25s	remaining: 1.88s
# 930:	total: 25s	remaining: 1.85s
# 931:	total: 25s	remaining: 1.83s
# 932:	total: 25.1s	remaining: 1.8s
# 933:	total: 25.1s	remaining: 1.77s
# 934:	total: 25.1s	remaining: 1.74s
# 935:	total: 25.1s	remaining: 1.72s
# 936:	total: 25.1s	remaining: 1.69s
# 937:	total: 25.2s	remaining: 1.66s
# 938:	total: 25.2s	remaining: 1.64s
# 939:	total: 25.2s	remaining: 1.61s
# 940:	total: 25.3s	remaining: 1.58s
# 941:	total: 25.3s	remaining: 1.56s
# 942:	total: 25.3s	remaining: 1.53s
# 943:	total: 25.3s	remaining: 1.5s
# 944:	total: 25.3s	remaining: 1.47s
# 945:	total: 25.4s	remaining: 1.45s
# 946:	total: 25.4s	remaining: 1.42s
# 947:	total: 25.4s	remaining: 1.39s
# 948:	total: 25.4s	remaining: 1.37s
# 949:	total: 25.5s	remaining: 1.34s
# 950:	total: 25.5s	remaining: 1.31s
# 951:	total: 25.5s	remaining: 1.28s
# 952:	total: 25.5s	remaining: 1.26s
# 953:	total: 25.6s	remaining: 1.23s
# 954:	total: 25.6s	remaining: 1.21s
# 955:	total: 25.6s	remaining: 1.18s
# 956:	total: 25.6s	remaining: 1.15s
# 957:	total: 25.6s	remaining: 1.12s
# 958:	total: 25.7s	remaining: 1.1s
# 959:	total: 25.7s	remaining: 1.07s
# 960:	total: 25.7s	remaining: 1.04s
# 961:	total: 25.7s	remaining: 1.02s
# 962:	total: 25.8s	remaining: 990ms
# 963:	total: 25.8s	remaining: 963ms
# 964:	total: 25.8s	remaining: 936ms
# 965:	total: 25.8s	remaining: 909ms
# 966:	total: 25.9s	remaining: 883ms
# 967:	total: 25.9s	remaining: 856ms
# 968:	total: 25.9s	remaining: 829ms
# 969:	total: 25.9s	remaining: 802ms
# 970:	total: 26s	remaining: 775ms
# 971:	total: 26s	remaining: 748ms
# 972:	total: 26s	remaining: 722ms
# 973:	total: 26s	remaining: 695ms
# 974:	total: 26.1s	remaining: 668ms
# 975:	total: 26.1s	remaining: 641ms
# 976:	total: 26.1s	remaining: 615ms
# 977:	total: 26.1s	remaining: 588ms
# 978:	total: 26.2s	remaining: 561ms
# 979:	total: 26.2s	remaining: 534ms
# 980:	total: 26.2s	remaining: 508ms
# 981:	total: 26.2s	remaining: 481ms
# 982:	total: 26.3s	remaining: 454ms
# 983:	total: 26.3s	remaining: 427ms
# 984:	total: 26.3s	remaining: 401ms
# 985:	total: 26.3s	remaining: 374ms
# 986:	total: 26.4s	remaining: 347ms
# 987:	total: 26.4s	remaining: 320ms
# 988:	total: 26.4s	remaining: 294ms
# 989:	total: 26.4s	remaining: 267ms
# 990:	total: 26.5s	remaining: 240ms
# 991:	total: 26.5s	remaining: 214ms
# 992:	total: 26.5s	remaining: 187ms
# 993:	total: 26.5s	remaining: 160ms
# 994:	total: 26.5s	remaining: 133ms
# 995:	total: 26.6s	remaining: 107ms
# 996:	total: 26.6s	remaining: 80ms
# 997:	total: 26.6s	remaining: 53.3ms
# 998:	total: 26.6s	remaining: 26.7ms
# 999:	total: 26.7s	remaining: 0us

# %%
y_pred = cat.predict(X_test_res)
print(confusion_matrix(y_test_res,y_pred))
print(accuracy_score(y_test_res,y_pred))
print(classification_report(y_test_res,y_pred))
# Out:
# [[21501  1216]
#  [ 2818 19899]]
# 0.9112118677642295
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91     22717
#            1       0.94      0.88      0.91     22717
#
#     accuracy                           0.91     45434
#    macro avg       0.91      0.91      0.91     45434
# weighted avg       0.91      0.91      0.91     45434

# %%
metrics.plot_roc_curve(cat, X_test, y_test)
metrics.roc_auc_score(y_test_res, y_pred, average=None)
# Out:
# E:\Python\Python39\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# 0.9112118677642295

# %%
rf=RandomForestClassifier()
rf.fit(X_train_res,y_train_res)
# Out:
# RandomForestClassifier()

# %%
y_pred1 = rf.predict(X_test_res)
print(confusion_matrix(y_test_res,y_pred1))
print(accuracy_score(y_test_res,y_pred1))
print(classification_report(y_test_res,y_pred1))
# Out:
# [[20605  2112]
#  [ 4181 18536]]
# 0.8614913941101378
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87     22717
#            1       0.90      0.82      0.85     22717
#
#     accuracy                           0.86     45434
#    macro avg       0.86      0.86      0.86     45434
# weighted avg       0.86      0.86      0.86     45434

# %%
metrics.plot_roc_curve(rf, X_test, y_test)
metrics.roc_auc_score(y_test_res, y_pred1, average=None)
# Out:
# E:\Python\Python39\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# 0.8614913941101376

# %%
logreg = LogisticRegression()
logreg.fit(X_train_res, y_train_res)
# Out:
# E:\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred2 = logreg.predict(X_test_res)
print(confusion_matrix(y_test_res,y_pred2))
print(accuracy_score(y_test_res,y_pred2))
print(classification_report(y_test_res,y_pred2))
# Out:
# [[17505  5212]
#  [ 5300 17417]]
# 0.7686314214024739
#               precision    recall  f1-score   support
#
#            0       0.77      0.77      0.77     22717
#            1       0.77      0.77      0.77     22717
#
#     accuracy                           0.77     45434
#    macro avg       0.77      0.77      0.77     45434
# weighted avg       0.77      0.77      0.77     45434

# %%
metrics.plot_roc_curve(logreg, X_test, y_test)
metrics.roc_auc_score(y_test_res, y_pred2, average=None)
# Out:
# E:\Python\Python39\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# 0.768631421402474

# %%
gnb = GaussianNB()
gnb.fit(X_train_res, y_train_res)
# Out:
# GaussianNB()

# %%
y_pred3 = gnb.predict(X_test_res)
print(confusion_matrix(y_test_res,y_pred3))
print(accuracy_score(y_test_res,y_pred3))
print(classification_report(y_test_res,y_pred3))
# Out:
# [[17078  5639]
#  [ 5712 17005]]
# 0.7501650746137254
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75     22717
#            1       0.75      0.75      0.75     22717
#
#     accuracy                           0.75     45434
#    macro avg       0.75      0.75      0.75     45434
# weighted avg       0.75      0.75      0.75     45434

# %%
metrics.plot_roc_curve(gnb, X_test, y_test)
metrics.roc_auc_score(y_test_res, y_pred3, average=None)
# Out:
# E:\Python\Python39\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# 0.7501650746137254

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train_res, y_train_res)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred4 = knn.predict(X_test_res)
print(confusion_matrix(y_test_res,y_pred4))
print(accuracy_score(y_test_res,y_pred4))
print(classification_report(y_test_res,y_pred4))
# Out:
# [[17306  5411]
#  [ 5984 16733]]
# 0.7491966368798697
#               precision    recall  f1-score   support
#
#            0       0.74      0.76      0.75     22717
#            1       0.76      0.74      0.75     22717
#
#     accuracy                           0.75     45434
#    macro avg       0.75      0.75      0.75     45434
# weighted avg       0.75      0.75      0.75     45434

# %%
metrics.plot_roc_curve(knn, X_test, y_test)
metrics.roc_auc_score(y_test_res, y_pred4, average=None)
# Out:
# E:\Python\Python39\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# 0.7491966368798697

# %%
xgb = XGBClassifier()
xgb.fit(X_train_res, y_train_res)
# Out:
# E:\Python\Python39\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# E:\Python\Python39\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [16:33:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred5 = xgb.predict(X_test_res)
print(confusion_matrix(y_test_res,y_pred5))
print(accuracy_score(y_test_res,y_pred5))
print(classification_report(y_test_res,y_pred5))
# Out:
# [[21402  1315]
#  [ 2858 19859]]
# 0.9081524849231852
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91     22717
#            1       0.94      0.87      0.90     22717
#
#     accuracy                           0.91     45434
#    macro avg       0.91      0.91      0.91     45434
# weighted avg       0.91      0.91      0.91     45434
# E:\Python\Python39\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):

# %%
metrics.plot_roc_curve(xgb, X_test, y_test)
metrics.roc_auc_score(y_test_res, y_pred6, average=None)
# Out:
# E:\Python\Python39\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# E:\Python\Python39\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# 0.9081524849231853

# %%
svc = SVC()
svc.fit(X_train_res, y_train_res)

# %%
y_pred6 = svc.predict(X_test_res)
print(confusion_matrix(y_test_res,y_pred6))
print(accuracy_score(y_test_res,y_pred6))
print(classification_report(y_test_res,y_pred6))
# Out:
# [[17824  4893]
#  [ 1594  4781]]
# 0.7770177368348687
#               precision    recall  f1-score   support
#
#            0       0.92      0.78      0.85     22717
#            1       0.49      0.75      0.60      6375
#
#     accuracy                           0.78     29092
#    macro avg       0.71      0.77      0.72     29092
# weighted avg       0.83      0.78      0.79     29092

# %%
metrics.plot_roc_curve(svc, X_test, y_test)
metrics.roc_auc_score(y_test_res, y_pred5, average=None)
# Out:
# 0.7672857141624093

# %%
joblib.dump(rf, "rf.pkl")
joblib.dump(cat, "cat.pkl")
joblib.dump(logreg, "logreg.pkl")
joblib.dump(gnb, "gnb.pkl")
joblib.dump(knn, "knn.pkl")
joblib.dump(svc, "svc.pkl")
joblib.dump(xgb, "xgb.pkl")
# Out:
# ['xgb.pkl']
